# %%
# %pip install tensorflow-probability==0.15.0

# %%
# magic command for automatic reload of python modules without needing to restart the notebook
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import scipy as sc
import tensorflow as tf
import tensorflow_probability as tfp
tfd=tfp.distributions
tfb=tfp.bijectors
from scipy import io
import time
import matplotlib.pyplot as plt
from sklearn import mixture
import joblib as jbl
import sys
import sklearn
import pandas as pd
from mixture_models import GMCM, GMC
import utils_v1 as utl

# adding path to the data folder
sys.path.append('real_world_data/')
from gas import GAS
from power import POWER
from miniboone import MINIBOONE

# %%
data_sets = ['GAS','POWER','MINIBOONE']
n_reps,mini_batch,max_training_iters = 10,50,20000
ll_list = []

density_estimation={} #initializing dict to 
for i in range(len(data_sets)):
    if data_sets[i] == 'GAS':
        gg=GAS()
    elif data_sets[i] == 'POWER':
        gg=POWER()
    elif data_sets[i] == 'HEPMASS':
        gg=HEPMASS()
    elif data_sets[i] == 'MINIBOONE':
        gg=MINIBOONE()

    data_trn = gg.trn.x
    data_tst = gg.tst.x
    data_vld = gg.val.x
    data_all = np.concatenate([data_trn,data_tst,data_vld],axis=0).astype('float32')
    print(f'Number of samples (before downsampling) = {data_all.shape[0]}, Number of dimensions = {data_all.shape[1]}')
    
    # gathering extreme points for each dimension (to be included in the training set)
    extreme_points=np.concatenate([np.argmin(data_all,axis=0), np.argmax(data_all,axis=0)])
    
    log_like_test=np.zeros(n_reps)
    for j in range(n_reps):
        data_trn=data_all[extreme_points,:] # initializing training set with extreme points
        np.random.seed(j)
        rand_id=np.random.permutation(data_all.shape[0])
        trn_id,vld_id,tst_id,_=np.split(rand_id,[10000,11000,12000])
        data_trn=np.concatenate((data_trn,data_all[trn_id,:]),axis=0) 
        data_vld=data_all[vld_id,:]
        data_tst=data_all[tst_id,:]

        nsamps,ndims = data_trn.shape
        print(f'Number of training samples (after downsampling) = {data_trn.shape[0]}, Number of dimensions = {ndims}')

        # Defining a preprocessing bijective transform (eg, log transform in this case)  
        min_val = (np.min(data_all)-3*np.std(data_all)).astype('float32')
        log_transform = tfb.Chain([tfb.Shift(shift=min_val),tfb.Exp()])

        # Training GMCM with data transformation
        # Initialing GMCM object and fitting the distribution 
        gmcm_obj=GMCM(ndims, data_transform=log_transform)
        nll_train, nll_vld=gmcm_obj.fit_dist_IFM(data_trn,
                                                 n_comps=40,
                                                 #data_vld=data_vld,
                                                 batch_size=mini_batch,
                                                 max_iters=max_training_iters,
                                                 regularize=True,
                                                 print_interval=500,
                                                 optimizer = tf.optimizers.Adam(learning_rate=1E-3))


#         # identifying the best iteration from validation error
#         non_nan_ids=[e for e in range(len(nll_vld)) if np.isfinite(nll_vld[e])]
#         nll_vld_smooth=utl.moving_average(nll_vld[non_nan_ids],5)
#         best_training_iters=non_nan_ids[np.argmin(nll_vld_smooth)+5]

#         # Training GMCM again with the specified number of iteration
#         # Initialing GMCM object and fitting the distribution 
#         gmcm_obj_best_fit=GMCM(ndims, data_transform=log_transform)
#         nll_train, nll_vld=gmcm_obj_best_fit.fit_dist_IFM(data_trn,
#                                                           n_comps=40,
#                                                           batch_size=mini_batch,
#                                                           max_iters=best_training_iters,
#                                                           optimizer = tf.optimizers.Adam(learning_rate=1E-4))




        log_like_test[j]=np.mean(gmcm_obj.distribution.log_prob(data_tst))
        density_estimation[data_sets[i]]=log_like_test
        print(density_estimation)
        jbl.dump(density_estimation,'DE_results_no_validation_20K')
# Out:
# Number of samples (before downsampling) = 1052065, Number of dimensions = 8
# Number of training samples (after downsampling) = 10016, Number of dimensions = 8
# 2023-01-06 18:01:37.554568: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-01-06 18:01:37.554631: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ip-172-16-4-60.ec2.internal): /proc/driver/nvidia/version does not exist
# 2023-01-06 18:01:37.557933: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Learning Marginals
# Marginals learnt in 47.15 s.
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow2_p38/lib/python3.8/site-packages/tensorflow_probability/python/distributions/distribution.py:342: calling MultivariateNormalDiag.__init__ (from tensorflow_probability.python.distributions.mvn_diag) with scale_identity_multiplier is deprecated and will be removed after 2020-01-01.
# Instructions for updating:
# `scale_identity_multiplier` is deprecated; please combine it into `scale_diag` directly instead.
# @ Iter:0,                         Training error: 0.1,                         Validation error: nan,                         Time Elapsed: 31.7 s
# @ Iter:500,                         Training error: -6.0,                         Validation error: nan,                         Time Elapsed: 76.1 s
# @ Iter:1000,                         Training error: -8.2,                         Validation error: nan,                         Time Elapsed: 121.1 s
# @ Iter:1500,                         Training error: -9.5,                         Validation error: nan,                         Time Elapsed: 167.2 s
# @ Iter:2000,                         Training error: -9.9,                         Validation error: nan,                         Time Elapsed: 216.7 s
# @ Iter:2500,                         Training error: -10.5,                         Validation error: nan,                         Time Elapsed: 262.2 s
# @ Iter:3000,                         Training error: -11.0,                         Validation error: nan,                         Time Elapsed: 307.2 s
# @ Iter:3500,                         Training error: -11.1,                         Validation error: nan,                         Time Elapsed: 353.2 s
# @ Iter:4000,                         Training error: -10.6,                         Validation error: nan,                         Time Elapsed: 404.1 s
# @ Iter:4500,                         Training error: -12.0,                         Validation error: nan,                         Time Elapsed: 450.7 s
# @ Iter:5000,                         Training error: -11.6,                         Validation error: nan,                         Time Elapsed: 498.8 s
# @ Iter:5500,                         Training error: -10.9,                         Validation error: nan,                         Time Elapsed: 545.4 s
# @ Iter:6000,                         Training error: -10.6,                         Validation error: nan,                         Time Elapsed: 596.9 s
# @ Iter:6500,                         Training error: -12.4,                         Validation error: nan,                         Time Elapsed: 644.9 s
# @ Iter:7000,                         Training error: -11.3,                         Validation error: nan,                         Time Elapsed: 693.3 s
# @ Iter:7500,                         Training error: -11.6,                         Validation error: nan,                         Time Elapsed: 746.7 s
# @ Iter:8000,                         Training error: -11.6,                         Validation error: nan,                         Time Elapsed: 795.3 s
# @ Iter:8500,                         Training error: -11.6,                         Validation error: nan,                         Time Elapsed: 844.7 s
# @ Iter:9000,                         Training error: -11.6,                         Validation error: nan,                         Time Elapsed: 893.9 s
# @ Iter:9500,                         Training error: -12.0,                         Validation error: nan,                         Time Elapsed: 947.5 s
# @ Iter:10000,                         Training error: -11.3,                         Validation error: nan,                         Time Elapsed: 997.1 s
# @ Iter:10500,                         Training error: -11.6,                         Validation error: nan,                         Time Elapsed: 1046.4 s
# @ Iter:11000,                         Training error: -10.7,                         Validation error: nan,                         Time Elapsed: 1101.4 s
# @ Iter:11500,                         Training error: -12.6,                         Validation error: nan,                         Time Elapsed: 1151.0 s
# @ Iter:12000,                         Training error: -12.0,                         Validation error: nan,                         Time Elapsed: 1201.5 s
# @ Iter:12500,                         Training error: -11.1,                         Validation error: nan,                         Time Elapsed: 1252.4 s
# @ Iter:13000,                         Training error: -11.3,                         Validation error: nan,                         Time Elapsed: 1307.7 s
# @ Iter:13500,                         Training error: -12.0,                         Validation error: nan,                         Time Elapsed: 1358.8 s
# @ Iter:14000,                         Training error: -11.5,                         Validation error: nan,                         Time Elapsed: 1409.7 s
# @ Iter:14500,                         Training error: -12.1,                         Validation error: nan,                         Time Elapsed: 1465.6 s
# @ Iter:15000,                         Training error: -12.1,                         Validation error: nan,                         Time Elapsed: 1516.4 s
# @ Iter:15500,                         Training error: -12.1,                         Validation error: nan,                         Time Elapsed: 1567.4 s
# @ Iter:16000,                         Training error: -12.1,                         Validation error: nan,                         Time Elapsed: 1618.5 s
# @ Iter:16500,                         Training error: -11.6,                         Validation error: nan,                         Time Elapsed: 1674.8 s
# @ Iter:17000,                         Training error: -12.0,                         Validation error: nan,                         Time Elapsed: 1726.7 s
# @ Iter:17500,                         Training error: -12.0,                         Validation error: nan,                         Time Elapsed: 1777.1 s
# @ Iter:18000,                         Training error: -11.6,                         Validation error: nan,                         Time Elapsed: 1832.6 s
# @ Iter:18500,                         Training error: -11.7,                         Validation error: nan,                         Time Elapsed: 1884.7 s
# @ Iter:19000,                         Training error: -11.4,                         Validation error: nan,                         Time Elapsed: 1936.1 s
# @ Iter:19500,                         Training error: -12.1,                         Validation error: nan,                         Time Elapsed: 1989.8 s
# {'GAS': array([4.41135073, 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.        , 0.        ])}
# Number of training samples (after downsampling) = 10016, Number of dimensions = 8
# Learning Marginals
# Marginals learnt in 51.82 s.
# @ Iter:0,                         Training error: -0.1,                         Validation error: nan,                         Time Elapsed: 28.2 s
# @ Iter:500,                         Training error: -5.6,                         Validation error: nan,                         Time Elapsed: 76.6 s
# @ Iter:1000,                         Training error: -8.0,                         Validation error: nan,                         Time Elapsed: 122.0 s
# @ Iter:1500,                         Training error: -9.2,                         Validation error: nan,                         Time Elapsed: 168.5 s
# @ Iter:2000,                         Training error: -10.0,                         Validation error: nan,                         Time Elapsed: 212.8 s
# @ Iter:2500,                         Training error: -11.1,                         Validation error: nan,                         Time Elapsed: 261.8 s
# @ Iter:3000,                         Training error: -11.1,                         Validation error: nan,                         Time Elapsed: 308.9 s
# @ Iter:3500,                         Training error: -11.1,                         Validation error: nan,                         Time Elapsed: 354.7 s
# @ Iter:4000,                         Training error: -11.2,                         Validation error: nan,                         Time Elapsed: 400.9 s
# @ Iter:4500,                         Training error: -11.8,                         Validation error: nan,                         Time Elapsed: 451.4 s
# @ Iter:5000,                         Training error: -11.1,                         Validation error: nan,                         Time Elapsed: 498.8 s
# @ Iter:5500,                         Training error: -11.4,                         Validation error: nan,                         Time Elapsed: 545.0 s
# @ Iter:6000,                         Training error: -11.9,                         Validation error: nan,                         Time Elapsed: 591.0 s
# @ Iter:6500,                         Training error: -12.1,                         Validation error: nan,                         Time Elapsed: 642.0 s
# @ Iter:7000,                         Training error: -11.9,                         Validation error: nan,                         Time Elapsed: 689.0 s
# @ Iter:7500,                         Training error: -11.9,                         Validation error: nan,                         Time Elapsed: 736.2 s
# @ Iter:8000,                         Training error: -11.7,                         Validation error: nan,                         Time Elapsed: 783.6 s
# @ Iter:8500,                         Training error: -12.3,                         Validation error: nan,                         Time Elapsed: 835.3 s
# @ Iter:9000,                         Training error: -10.9,                         Validation error: nan,                         Time Elapsed: 883.0 s
# @ Iter:9500,                         Training error: -11.3,                         Validation error: nan,                         Time Elapsed: 930.7 s
# @ Iter:10000,                         Training error: -11.3,                         Validation error: nan,                         Time Elapsed: 983.1 s
# @ Iter:10500,                         Training error: -12.0,                         Validation error: nan,                         Time Elapsed: 1031.4 s
# @ Iter:11000,                         Training error: -11.4,                         Validation error: nan,                         Time Elapsed: 1080.0 s
# @ Iter:11500,                         Training error: -12.5,                         Validation error: nan,                         Time Elapsed: 1129.4 s
# @ Iter:12000,                         Training error: -11.5,                         Validation error: nan,                         Time Elapsed: 1182.9 s
# @ Iter:12500,                         Training error: -12.4,                         Validation error: nan,                         Time Elapsed: 1232.8 s
# @ Iter:13000,                         Training error: -12.4,                         Validation error: nan,                         Time Elapsed: 1282.7 s
# @ Iter:13500,                         Training error: -12.0,                         Validation error: nan,                         Time Elapsed: 1337.5 s
# @ Iter:14000,                         Training error: -11.6,                         Validation error: nan,                         Time Elapsed: 1391.8 s
# @ Iter:14500,                         Training error: -11.6,                         Validation error: nan,                         Time Elapsed: 1443.5 s
# @ Iter:15000,                         Training error: -11.5,                         Validation error: nan,                         Time Elapsed: 1495.1 s
# @ Iter:15500,                         Training error: -12.5,                         Validation error: nan,                         Time Elapsed: 1550.1 s
# @ Iter:16000,                         Training error: -12.5,                         Validation error: nan,                         Time Elapsed: 1601.0 s
# @ Iter:16500,                         Training error: -12.4,                         Validation error: nan,                         Time Elapsed: 1652.6 s
# @ Iter:17000,                         Training error: -12.3,                         Validation error: nan,                         Time Elapsed: 1708.0 s
# @ Iter:17500,                         Training error: -12.8,                         Validation error: nan,                         Time Elapsed: 1760.0 s
# @ Iter:18000,                         Training error: -12.1,                         Validation error: nan,                         Time Elapsed: 1811.2 s
# @ Iter:18500,                         Training error: -12.1,                         Validation error: nan,                         Time Elapsed: 1863.4 s
# @ Iter:19000,                         Training error: -12.3,                         Validation error: nan,                         Time Elapsed: 1919.3 s
# @ Iter:19500,                         Training error: -12.3,                         Validation error: nan,                         Time Elapsed: 1972.4 s
# {'GAS': array([4.41135073, 4.57755375, 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.        , 0.        ])}
# Number of training samples (after downsampling) = 10016, Number of dimensions = 8
# Learning Marginals
# Marginals learnt in 57.94 s.
# @ Iter:0,                         Training error: 0.6,                         Validation error: nan,                         Time Elapsed: 29.2 s
# @ Iter:500,                         Training error: -5.8,                         Validation error: nan,                         Time Elapsed: 73.9 s
# @ Iter:1000,                         Training error: -8.4,                         Validation error: nan,                         Time Elapsed: 119.6 s
# @ Iter:1500,                         Training error: -9.3,                         Validation error: nan,                         Time Elapsed: 169.0 s
# @ Iter:2000,                         Training error: -10.2,                         Validation error: nan,                         Time Elapsed: 212.2 s
# @ Iter:2500,                         Training error: -10.6,                         Validation error: nan,                         Time Elapsed: 255.3 s
# @ Iter:3000,                         Training error: -11.2,                         Validation error: nan,                         Time Elapsed: 300.9 s
# @ Iter:3500,                         Training error: -10.5,                         Validation error: nan,                         Time Elapsed: 350.0 s
# @ Iter:4000,                         Training error: -10.8,                         Validation error: nan,                         Time Elapsed: 394.7 s
# @ Iter:4500,                         Training error: -11.2,                         Validation error: nan,                         Time Elapsed: 440.1 s
# @ Iter:5000,                         Training error: -12.3,                         Validation error: nan,                         Time Elapsed: 486.8 s
# @ Iter:5500,                         Training error: -11.8,                         Validation error: nan,                         Time Elapsed: 537.7 s
# @ Iter:6000,                         Training error: -11.0,                         Validation error: nan,                         Time Elapsed: 584.2 s
# @ Iter:6500,                         Training error: -11.2,                         Validation error: nan,                         Time Elapsed: 631.0 s
# @ Iter:7000,                         Training error: -11.0,                         Validation error: nan,                         Time Elapsed: 680.8 s
# @ Iter:7500,                         Training error: -11.9,                         Validation error: nan,                         Time Elapsed: 730.3 s
# @ Iter:8000,                         Training error: -11.9,                         Validation error: nan,                         Time Elapsed: 777.5 s
# @ Iter:8500,                         Training error: -11.7,                         Validation error: nan,                         Time Elapsed: 824.9 s
# @ Iter:9000,                         Training error: -11.3,                         Validation error: nan,                         Time Elapsed: 876.2 s
# @ Iter:9500,                         Training error: -11.7,                         Validation error: nan,                         Time Elapsed: 924.2 s
# @ Iter:10000,                         Training error: -12.0,                         Validation error: nan,                         Time Elapsed: 973.0 s
# @ Iter:10500,                         Training error: -11.7,                         Validation error: nan,                         Time Elapsed: 1020.3 s
# @ Iter:11000,                         Training error: -11.3,                         Validation error: nan,                         Time Elapsed: 1073.5 s
# @ Iter:11500,                         Training error: -11.0,                         Validation error: nan,                         Time Elapsed: 1120.9 s
# @ Iter:12000,                         Training error: -11.4,                         Validation error: nan,                         Time Elapsed: 1170.3 s
# @ Iter:12500,                         Training error: -12.0,                         Validation error: nan,                         Time Elapsed: 1222.1 s
# @ Iter:13000,                         Training error: -11.1,                         Validation error: nan,                         Time Elapsed: 1272.4 s
# @ Iter:13500,                         Training error: -11.7,                         Validation error: nan,                         Time Elapsed: 1322.1 s
# @ Iter:14000,                         Training error: -11.4,                         Validation error: nan,                         Time Elapsed: 1371.0 s
# @ Iter:14500,                         Training error: -11.6,                         Validation error: nan,                         Time Elapsed: 1424.8 s
# @ Iter:15000,                         Training error: -10.9,                         Validation error: nan,                         Time Elapsed: 1474.2 s
# @ Iter:15500,                         Training error: -11.6,                         Validation error: nan,                         Time Elapsed: 1524.1 s
# @ Iter:16000,                         Training error: -11.7,                         Validation error: nan,                         Time Elapsed: 1573.6 s
# @ Iter:16500,                         Training error: -12.3,                         Validation error: nan,                         Time Elapsed: 1627.9 s
# @ Iter:17000,                         Training error: -11.7,                         Validation error: nan,                         Time Elapsed: 1678.5 s
# @ Iter:17500,                         Training error: -11.4,                         Validation error: nan,                         Time Elapsed: 1729.3 s
# @ Iter:18000,                         Training error: -11.2,                         Validation error: nan,                         Time Elapsed: 1784.5 s
# @ Iter:18500,                         Training error: -12.4,                         Validation error: nan,                         Time Elapsed: 1834.5 s
# @ Iter:19000,                         Training error: -12.1,                         Validation error: nan,                         Time Elapsed: 1885.6 s
# @ Iter:19500,                         Training error: -12.3,                         Validation error: nan,                         Time Elapsed: 1938.8 s
# {'GAS': array([4.41135073, 4.57755375, 4.24145985, 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.        , 0.        ])}
# Number of training samples (after downsampling) = 10016, Number of dimensions = 8
# Learning Marginals
# Marginals learnt in 51.27 s.
# @ Iter:0,                         Training error: 0.2,                         Validation error: nan,                         Time Elapsed: 28.3 s
# @ Iter:500,                         Training error: -5.5,                         Validation error: nan,                         Time Elapsed: 76.6 s
# @ Iter:1000,                         Training error: -8.2,                         Validation error: nan,                         Time Elapsed: 122.1 s
# @ Iter:1500,                         Training error: -8.7,                         Validation error: nan,                         Time Elapsed: 167.9 s
# @ Iter:2000,                         Training error: -10.0,                         Validation error: nan,                         Time Elapsed: 214.5 s
# @ Iter:2500,                         Training error: -10.7,                         Validation error: nan,                         Time Elapsed: 262.6 s
# @ Iter:3000,                         Training error: -10.0,                         Validation error: nan,                         Time Elapsed: 306.9 s
# @ Iter:3500,                         Training error: -11.0,                         Validation error: nan,                         Time Elapsed: 352.4 s
# @ Iter:4000,                         Training error: -11.6,                         Validation error: nan,                         Time Elapsed: 398.3 s
# @ Iter:4500,                         Training error: -11.8,                         Validation error: nan,                         Time Elapsed: 448.7 s
# @ Iter:5000,                         Training error: -11.6,                         Validation error: nan,                         Time Elapsed: 501.9 s
# @ Iter:5500,                         Training error: -11.2,                         Validation error: nan,                         Time Elapsed: 549.9 s
# @ Iter:6000,                         Training error: -11.6,                         Validation error: nan,                         Time Elapsed: 598.0 s
# @ Iter:6500,                         Training error: -11.2,                         Validation error: nan,                         Time Elapsed: 649.8 s
# @ Iter:7000,                         Training error: -11.6,                         Validation error: nan,                         Time Elapsed: 698.3 s
# @ Iter:7500,                         Training error: -11.9,                         Validation error: nan,                         Time Elapsed: 747.3 s
# @ Iter:8000,                         Training error: -11.4,                         Validation error: nan,                         Time Elapsed: 802.0 s
# @ Iter:8500,                         Training error: -12.2,                         Validation error: nan,                         Time Elapsed: 855.0 s
# @ Iter:9000,                         Training error: -11.9,                         Validation error: nan,                         Time Elapsed: 906.3 s
# @ Iter:9500,                         Training error: -10.9,                         Validation error: nan,                         Time Elapsed: 957.7 s
# @ Iter:10000,                         Training error: -11.6,                         Validation error: nan,                         Time Elapsed: 1013.1 s
# @ Iter:10500,                         Training error: -12.0,                         Validation error: nan,                         Time Elapsed: 1064.3 s
# @ Iter:11000,                         Training error: -11.7,                         Validation error: nan,                         Time Elapsed: 1116.2 s
# @ Iter:11500,                         Training error: -12.2,                         Validation error: nan,                         Time Elapsed: 1173.4 s
# @ Iter:12000,                         Training error: -11.7,                         Validation error: nan,                         Time Elapsed: 1224.7 s
# @ Iter:12500,                         Training error: -11.7,                         Validation error: nan,                         Time Elapsed: 1276.1 s
# @ Iter:13000,                         Training error: -11.7,                         Validation error: nan,                         Time Elapsed: 1331.9 s
# @ Iter:13500,                         Training error: -12.5,                         Validation error: nan,                         Time Elapsed: 1383.8 s
# @ Iter:14000,                         Training error: -12.9,                         Validation error: nan,                         Time Elapsed: 1437.0 s
# @ Iter:14500,                         Training error: -13.0,                         Validation error: nan,                         Time Elapsed: 1489.0 s
# @ Iter:15000,                         Training error: -13.1,                         Validation error: nan,                         Time Elapsed: 1545.0 s
# @ Iter:15500,                         Training error: -12.2,                         Validation error: nan,                         Time Elapsed: 1596.7 s
# @ Iter:16000,                         Training error: -11.9,                         Validation error: nan,                         Time Elapsed: 1648.5 s
# @ Iter:16500,                         Training error: -12.1,                         Validation error: nan,                         Time Elapsed: 1704.6 s
# @ Iter:17000,                         Training error: -12.6,                         Validation error: nan,                         Time Elapsed: 1756.3 s
# @ Iter:17500,                         Training error: -12.6,                         Validation error: nan,                         Time Elapsed: 1808.3 s
# @ Iter:18000,                         Training error: -12.2,                         Validation error: nan,                         Time Elapsed: 1861.3 s
# @ Iter:18500,                         Training error: -12.3,                         Validation error: nan,                         Time Elapsed: 1917.6 s
# @ Iter:19000,                         Training error: -12.2,                         Validation error: nan,                         Time Elapsed: 1969.2 s
# @ Iter:19500,                         Training error: -10.9,                         Validation error: nan,                         Time Elapsed: 2023.5 s
# {'GAS': array([4.41135073, 4.57755375, 4.24145985, 4.54454708, 0.        ,
#        0.        , 0.        , 0.        , 0.        , 0.        ])}
# Number of training samples (after downsampling) = 10016, Number of dimensions = 8
# Learning Marginals
# Marginals learnt in 49.17 s.
# @ Iter:0,                         Training error: 0.8,                         Validation error: nan,                         Time Elapsed: 28.3 s
# @ Iter:500,                         Training error: -5.4,                         Validation error: nan,                         Time Elapsed: 73.3 s
# @ Iter:1000,                         Training error: -8.3,                         Validation error: nan,                         Time Elapsed: 123.2 s
# @ Iter:1500,                         Training error: -9.5,                         Validation error: nan,                         Time Elapsed: 169.0 s
# @ Iter:2000,                         Training error: -10.0,                         Validation error: nan,                         Time Elapsed: 215.4 s
# @ Iter:2500,                         Training error: -10.8,                         Validation error: nan,                         Time Elapsed: 259.8 s
# @ Iter:3000,                         Training error: -10.1,                         Validation error: nan,                         Time Elapsed: 309.1 s
# @ Iter:3500,                         Training error: -11.2,                         Validation error: nan,                         Time Elapsed: 353.3 s
# @ Iter:4000,                         Training error: -10.7,                         Validation error: nan,                         Time Elapsed: 398.5 s
# @ Iter:4500,                         Training error: -11.6,                         Validation error: nan,                         Time Elapsed: 443.4 s
# @ Iter:5000,                         Training error: -10.9,                         Validation error: nan,                         Time Elapsed: 494.6 s
# @ Iter:5500,                         Training error: -11.5,                         Validation error: nan,                         Time Elapsed: 540.5 s
# @ Iter:6000,                         Training error: -11.3,                         Validation error: nan,                         Time Elapsed: 586.9 s
# @ Iter:6500,                         Training error: -11.5,                         Validation error: nan,                         Time Elapsed: 637.7 s
# @ Iter:7000,                         Training error: -11.4,                         Validation error: nan,                         Time Elapsed: 684.8 s
# @ Iter:7500,                         Training error: -11.9,                         Validation error: nan,                         Time Elapsed: 733.0 s
# @ Iter:8000,                         Training error: -10.9,                         Validation error: nan,                         Time Elapsed: 781.5 s
# @ Iter:8500,                         Training error: -11.1,                         Validation error: nan,                         Time Elapsed: 834.3 s
# @ Iter:9000,                         Training error: -12.1,                         Validation error: nan,                         Time Elapsed: 883.1 s
# @ Iter:9500,                         Training error: -11.5,                         Validation error: nan,                         Time Elapsed: 932.8 s
# @ Iter:10000,                         Training error: -11.4,                         Validation error: nan,                         Time Elapsed: 982.4 s
# @ Iter:10500,                         Training error: -12.2,                         Validation error: nan,                         Time Elapsed: 1035.9 s
# @ Iter:11000,                         Training error: -11.3,                         Validation error: nan,                         Time Elapsed: 1085.9 s
# @ Iter:11500,                         Training error: -11.5,                         Validation error: nan,                         Time Elapsed: 1136.1 s
# @ Iter:12000,                         Training error: -11.8,                         Validation error: nan,                         Time Elapsed: 1189.6 s
# @ Iter:12500,                         Training error: -10.8,                         Validation error: nan,                         Time Elapsed: 1239.7 s
# @ Iter:13000,                         Training error: -11.0,                         Validation error: nan,                         Time Elapsed: 1288.9 s
# @ Iter:13500,                         Training error: -12.3,                         Validation error: nan,                         Time Elapsed: 1339.5 s
# @ Iter:14000,                         Training error: -11.8,                         Validation error: nan,                         Time Elapsed: 1394.9 s
# @ Iter:14500,                         Training error: -11.9,                         Validation error: nan,                         Time Elapsed: 1446.2 s
# @ Iter:15000,                         Training error: -11.2,                         Validation error: nan,                         Time Elapsed: 1497.1 s
# @ Iter:15500,                         Training error: -10.9,                         Validation error: nan,                         Time Elapsed: 1552.6 s
# @ Iter:16000,                         Training error: -11.3,                         Validation error: nan,                         Time Elapsed: 1602.4 s
# @ Iter:16500,                         Training error: -12.9,                         Validation error: nan,                         Time Elapsed: 1653.9 s
# @ Iter:17000,                         Training error: -11.8,                         Validation error: nan,                         Time Elapsed: 1705.8 s
# @ Iter:17500,                         Training error: -11.2,                         Validation error: nan,                         Time Elapsed: 1759.6 s
# @ Iter:18000,                         Training error: -11.9,                         Validation error: nan,                         Time Elapsed: 1811.1 s
# @ Iter:18500,                         Training error: -12.2,                         Validation error: nan,                         Time Elapsed: 1861.2 s
# @ Iter:19000,                         Training error: -11.2,                         Validation error: nan,                         Time Elapsed: 1916.1 s
# @ Iter:19500,                         Training error: -12.2,                         Validation error: nan,                         Time Elapsed: 1966.1 s
# {'GAS': array([4.41135073, 4.57755375, 4.24145985, 4.54454708, 4.46260166,
#        0.        , 0.        , 0.        , 0.        , 0.        ])}
# Number of training samples (after downsampling) = 10016, Number of dimensions = 8
# Learning Marginals
# Marginals learnt in 57.28 s.
# @ Iter:0,                         Training error: 0.4,                         Validation error: nan,                         Time Elapsed: 28.8 s
# @ Iter:500,                         Training error: -4.9,                         Validation error: nan,                         Time Elapsed: 72.4 s
# @ Iter:1000,                         Training error: -7.7,                         Validation error: nan,                         Time Elapsed: 116.6 s
# @ Iter:1500,                         Training error: -9.3,                         Validation error: nan,                         Time Elapsed: 162.3 s
# @ Iter:2000,                         Training error: -10.5,                         Validation error: nan,                         Time Elapsed: 212.5 s
# @ Iter:2500,                         Training error: -10.3,                         Validation error: nan,                         Time Elapsed: 257.3 s
# @ Iter:3000,                         Training error: -10.7,                         Validation error: nan,                         Time Elapsed: 302.1 s
# @ Iter:3500,                         Training error: -11.0,                         Validation error: nan,                         Time Elapsed: 353.8 s
# @ Iter:4000,                         Training error: -10.2,                         Validation error: nan,                         Time Elapsed: 400.0 s
# @ Iter:4500,                         Training error: -10.7,                         Validation error: nan,                         Time Elapsed: 447.1 s
# @ Iter:5000,                         Training error: -11.1,                         Validation error: nan,                         Time Elapsed: 495.4 s
# @ Iter:5500,                         Training error: -11.0,                         Validation error: nan,                         Time Elapsed: 547.9 s
# @ Iter:6000,                         Training error: -11.0,                         Validation error: nan,                         Time Elapsed: 596.5 s
# @ Iter:6500,                         Training error: -11.4,                         Validation error: nan,                         Time Elapsed: 644.5 s
# @ Iter:7000,                         Training error: -11.6,                         Validation error: nan,                         Time Elapsed: 693.3 s
# @ Iter:7500,                         Training error: -11.0,                         Validation error: nan,                         Time Elapsed: 746.4 s
# @ Iter:8000,                         Training error: -11.0,                         Validation error: nan,                         Time Elapsed: 796.4 s
# @ Iter:8500,                         Training error: -11.3,                         Validation error: nan,                         Time Elapsed: 844.8 s
# @ Iter:9000,                         Training error: -11.1,                         Validation error: nan,                         Time Elapsed: 898.1 s
# @ Iter:9500,                         Training error: -11.5,                         Validation error: nan,                         Time Elapsed: 947.9 s
# @ Iter:10000,                         Training error: -10.9,                         Validation error: nan,                         Time Elapsed: 998.1 s
# @ Iter:10500,                         Training error: -11.8,                         Validation error: nan,                         Time Elapsed: 1051.0 s
# @ Iter:11000,                         Training error: -11.6,                         Validation error: nan,                         Time Elapsed: 1112.1 s
# @ Iter:11500,                         Training error: -12.6,                         Validation error: nan,                         Time Elapsed: 1165.9 s
# @ Iter:12000,                         Training error: -11.9,                         Validation error: nan,                         Time Elapsed: 1216.1 s
# @ Iter:12500,                         Training error: -11.7,                         Validation error: nan,                         Time Elapsed: 1270.6 s
# @ Iter:13000,                         Training error: -12.2,                         Validation error: nan,                         Time Elapsed: 1321.3 s
# @ Iter:13500,                         Training error: -11.7,                         Validation error: nan,                         Time Elapsed: 1371.9 s
# @ Iter:14000,                         Training error: -11.7,                         Validation error: nan,                         Time Elapsed: 1426.6 s
# @ Iter:14500,                         Training error: -12.2,                         Validation error: nan,                         Time Elapsed: 1478.5 s
# @ Iter:15000,                         Training error: -12.9,                         Validation error: nan,                         Time Elapsed: 1529.6 s
# @ Iter:15500,                         Training error: -11.9,                         Validation error: nan,                         Time Elapsed: 1580.7 s
# @ Iter:16000,                         Training error: -12.0,                         Validation error: nan,                         Time Elapsed: 1636.2 s
# @ Iter:16500,                         Training error: -11.7,                         Validation error: nan,                         Time Elapsed: 1688.9 s
# @ Iter:17000,                         Training error: -12.0,                         Validation error: nan,                         Time Elapsed: 1740.6 s
# @ Iter:17500,                         Training error: -12.2,                         Validation error: nan,                         Time Elapsed: 1796.8 s
# @ Iter:18000,                         Training error: -12.1,                         Validation error: nan,                         Time Elapsed: 1847.8 s
# @ Iter:18500,                         Training error: -11.9,                         Validation error: nan,                         Time Elapsed: 1899.6 s
# @ Iter:19000,                         Training error: -12.3,                         Validation error: nan,                         Time Elapsed: 1951.0 s
# @ Iter:19500,                         Training error: -12.2,                         Validation error: nan,                         Time Elapsed: 2008.4 s
# {'GAS': array([4.41135073, 4.57755375, 4.24145985, 4.54454708, 4.46260166,
#        4.53148937, 0.        , 0.        , 0.        , 0.        ])}
# Number of training samples (after downsampling) = 10016, Number of dimensions = 8
# Learning Marginals
# Marginals learnt in 48.34 s.
# @ Iter:0,                         Training error: 0.5,                         Validation error: nan,                         Time Elapsed: 30.1 s
# @ Iter:500,                         Training error: -5.5,                         Validation error: nan,                         Time Elapsed: 76.0 s
# @ Iter:1000,                         Training error: -8.2,                         Validation error: nan,                         Time Elapsed: 121.6 s
# @ Iter:1500,                         Training error: -9.1,                         Validation error: nan,                         Time Elapsed: 167.6 s
# @ Iter:2000,                         Training error: -10.1,                         Validation error: nan,                         Time Elapsed: 218.3 s
# @ Iter:2500,                         Training error: -10.8,                         Validation error: nan,                         Time Elapsed: 263.9 s
# @ Iter:3000,                         Training error: -11.0,                         Validation error: nan,                         Time Elapsed: 310.7 s
# @ Iter:3500,                         Training error: -10.7,                         Validation error: nan,                         Time Elapsed: 356.5 s
# @ Iter:4000,                         Training error: -10.9,                         Validation error: nan,                         Time Elapsed: 407.9 s
# @ Iter:4500,                         Training error: -10.5,                         Validation error: nan,                         Time Elapsed: 455.3 s
# @ Iter:5000,                         Training error: -11.1,                         Validation error: nan,                         Time Elapsed: 504.2 s
# @ Iter:5500,                         Training error: -10.8,                         Validation error: nan,                         Time Elapsed: 552.3 s
# @ Iter:6000,                         Training error: -10.8,                         Validation error: nan,                         Time Elapsed: 605.8 s
# @ Iter:6500,                         Training error: -11.7,                         Validation error: nan,                         Time Elapsed: 655.6 s
# @ Iter:7000,                         Training error: -12.0,                         Validation error: nan,                         Time Elapsed: 704.0 s
# @ Iter:7500,                         Training error: -11.1,                         Validation error: nan,                         Time Elapsed: 758.1 s
# @ Iter:8000,                         Training error: -12.6,                         Validation error: nan,                         Time Elapsed: 808.8 s
# @ Iter:8500,                         Training error: -11.4,                         Validation error: nan,                         Time Elapsed: 859.0 s
# @ Iter:9000,                         Training error: -10.9,                         Validation error: nan,                         Time Elapsed: 911.2 s
# @ Iter:9500,                         Training error: -11.0,                         Validation error: nan,                         Time Elapsed: 967.0 s
# @ Iter:10000,                         Training error: -10.7,                         Validation error: nan,                         Time Elapsed: 1018.5 s
# @ Iter:10500,                         Training error: -10.8,                         Validation error: nan,                         Time Elapsed: 1069.9 s
# @ Iter:11000,                         Training error: -11.2,                         Validation error: nan,                         Time Elapsed: 1127.5 s
# @ Iter:11500,                         Training error: -11.6,                         Validation error: nan,                         Time Elapsed: 1180.2 s
# @ Iter:12000,                         Training error: -11.8,                         Validation error: nan,                         Time Elapsed: 1233.2 s
# @ Iter:12500,                         Training error: -12.0,                         Validation error: nan,                         Time Elapsed: 1287.6 s
# @ Iter:13000,                         Training error: -12.6,                         Validation error: nan,                         Time Elapsed: 1344.9 s
# @ Iter:13500,                         Training error: -12.4,                         Validation error: nan,                         Time Elapsed: 1398.5 s
# @ Iter:14000,                         Training error: -12.6,                         Validation error: nan,                         Time Elapsed: 1453.1 s
# @ Iter:14500,                         Training error: -11.2,                         Validation error: nan,                         Time Elapsed: 1510.5 s
# @ Iter:15000,                         Training error: -12.4,                         Validation error: nan,                         Time Elapsed: 1565.7 s
# @ Iter:15500,                         Training error: -11.9,                         Validation error: nan,                         Time Elapsed: 1620.2 s
# @ Iter:16000,                         Training error: -10.8,                         Validation error: nan,                         Time Elapsed: 1682.8 s
# @ Iter:16500,                         Training error: -11.9,                         Validation error: nan,                         Time Elapsed: 1738.6 s
# @ Iter:17000,                         Training error: -11.8,                         Validation error: nan,                         Time Elapsed: 1794.1 s
# @ Iter:17500,                         Training error: -11.9,                         Validation error: nan,                         Time Elapsed: 1853.5 s
# @ Iter:18000,                         Training error: -11.6,                         Validation error: nan,                         Time Elapsed: 1908.9 s
# @ Iter:18500,                         Training error: -11.9,                         Validation error: nan,                         Time Elapsed: 1964.8 s
# @ Iter:19000,                         Training error: -13.0,                         Validation error: nan,                         Time Elapsed: 2025.2 s
# @ Iter:19500,                         Training error: -12.2,                         Validation error: nan,                         Time Elapsed: 2081.2 s
# {'GAS': array([4.41135073, 4.57755375, 4.24145985, 4.54454708, 4.46260166,
#        4.53148937, 4.55820704, 0.        , 0.        , 0.        ])}
# Number of training samples (after downsampling) = 10016, Number of dimensions = 8
# Learning Marginals
# Marginals learnt in 58.38 s.
# @ Iter:0,                         Training error: 0.1,                         Validation error: nan,                         Time Elapsed: 28.7 s
# @ Iter:500,                         Training error: -5.7,                         Validation error: nan,                         Time Elapsed: 73.4 s
# @ Iter:1000,                         Training error: -8.3,                         Validation error: nan,                         Time Elapsed: 117.7 s
# @ Iter:1500,                         Training error: -9.1,                         Validation error: nan,                         Time Elapsed: 164.4 s
# @ Iter:2000,                         Training error: -9.8,                         Validation error: nan,                         Time Elapsed: 212.5 s
# @ Iter:2500,                         Training error: -11.1,                         Validation error: nan,                         Time Elapsed: 256.6 s
# @ Iter:3000,                         Training error: -11.3,                         Validation error: nan,                         Time Elapsed: 302.9 s
# @ Iter:3500,                         Training error: -11.5,                         Validation error: nan,                         Time Elapsed: 355.5 s
# @ Iter:4000,                         Training error: -11.1,                         Validation error: nan,                         Time Elapsed: 404.2 s
# @ Iter:4500,                         Training error: -11.5,                         Validation error: nan,                         Time Elapsed: 453.2 s
# ...
# @ Iter:2500,                         Training error: -1.0,                         Validation error: nan,                         Time Elapsed: 205.5 s
# @ Iter:3000,                         Training error: -1.0,                         Validation error: nan,                         Time Elapsed: 246.3 s
# @ Iter:3500,                         Training error: -0.8,                         Validation error: nan,                         Time Elapsed: 282.1 s
# @ Iter:4000,                         Training error: -1.3,                         Validation error: nan,                         Time Elapsed: 318.4 s
# @ Iter:4500,                         Training error: -0.9,                         Validation error: nan,                         Time Elapsed: 354.4 s
# @ Iter:5000,                         Training error: -1.0,                         Validation error: nan,                         Time Elapsed: 395.2 s
# @ Iter:5500,                         Training error: -0.8,                         Validation error: nan,                         Time Elapsed: 433.1 s
# @ Iter:6000,                         Training error: -1.1,                         Validation error: nan,                         Time Elapsed: 469.1 s
# @ Iter:6500,                         Training error: -0.9,                         Validation error: nan,                         Time Elapsed: 506.4 s
# @ Iter:7000,                         Training error: -1.2,                         Validation error: nan,                         Time Elapsed: 543.3 s
# @ Iter:7500,                         Training error: -1.2,                         Validation error: nan,                         Time Elapsed: 584.9 s
# @ Iter:8000,                         Training error: -1.2,                         Validation error: nan,                         Time Elapsed: 621.8 s
# @ Iter:8500,                         Training error: -0.9,                         Validation error: nan,                         Time Elapsed: 658.8 s
# @ Iter:9000,                         Training error: -1.3,                         Validation error: nan,                         Time Elapsed: 696.1 s
# @ Iter:9500,                         Training error: -1.0,                         Validation error: nan,                         Time Elapsed: 733.6 s
# @ Iter:10000,                         Training error: -1.0,                         Validation error: nan,                         Time Elapsed: 775.1 s
# @ Iter:10500,                         Training error: -1.1,                         Validation error: nan,                         Time Elapsed: 811.7 s
# @ Iter:11000,                         Training error: -1.2,                         Validation error: nan,                         Time Elapsed: 849.2 s
# @ Iter:11500,                         Training error: -1.1,                         Validation error: nan,                         Time Elapsed: 886.2 s
# @ Iter:12000,                         Training error: -0.9,                         Validation error: nan,                         Time Elapsed: 923.6 s
# @ Iter:12500,                         Training error: -1.0,                         Validation error: nan,                         Time Elapsed: 965.0 s
# @ Iter:13000,                         Training error: -1.1,                         Validation error: nan,                         Time Elapsed: 1002.6 s
# @ Iter:13500,                         Training error: -1.1,                         Validation error: nan,                         Time Elapsed: 1039.7 s
# @ Iter:14000,                         Training error: -1.1,                         Validation error: nan,                         Time Elapsed: 1076.7 s
# @ Iter:14500,                         Training error: -1.0,                         Validation error: nan,                         Time Elapsed: 1117.3 s
# @ Iter:15000,                         Training error: -1.5,                         Validation error: nan,                         Time Elapsed: 1155.3 s
# @ Iter:15500,                         Training error: -1.2,                         Validation error: nan,                         Time Elapsed: 1193.1 s
# @ Iter:16000,                         Training error: -0.8,                         Validation error: nan,                         Time Elapsed: 1230.8 s
# @ Iter:16500,                         Training error: -1.2,                         Validation error: nan,                         Time Elapsed: 1268.9 s
# @ Iter:17000,                         Training error: -1.0,                         Validation error: nan,                         Time Elapsed: 1310.6 s
# @ Iter:17500,                         Training error: -1.1,                         Validation error: nan,                         Time Elapsed: 1349.5 s
# @ Iter:18000,                         Training error: -1.2,                         Validation error: nan,                         Time Elapsed: 1387.8 s
# @ Iter:18500,                         Training error: -0.9,                         Validation error: nan,                         Time Elapsed: 1426.3 s
# @ Iter:19000,                         Training error: -1.3,                         Validation error: nan,                         Time Elapsed: 1466.7 s
# @ Iter:19500,                         Training error: -1.4,                         Validation error: nan,                         Time Elapsed: 1507.1 s
# {'GAS': array([4.41135073, 4.57755375, 4.24145985, 4.54454708, 4.46260166,
#        4.53148937, 4.55820704, 4.66826868, 4.32659483, 4.64419651]), 'POWER': array([ 0.0482939 , -0.01393519,  0.19215031,  0.15966395, -0.05526834,
#         0.20700838,  0.09052471,  0.05195272,  0.08804642,  0.        ])}
# Number of training samples (after downsampling) = 10012, Number of dimensions = 6
# Learning Marginals
# Marginals learnt in 30.58 s.
# @ Iter:0,                         Training error: 0.1,                         Validation error: nan,                         Time Elapsed: 28.6 s
# @ Iter:500,                         Training error: -0.6,                         Validation error: nan,                         Time Elapsed: 64.9 s
# @ Iter:1000,                         Training error: -0.7,                         Validation error: nan,                         Time Elapsed: 101.5 s
# @ Iter:1500,                         Training error: -0.8,                         Validation error: nan,                         Time Elapsed: 137.2 s
# @ Iter:2000,                         Training error: -1.1,                         Validation error: nan,                         Time Elapsed: 173.6 s
# @ Iter:2500,                         Training error: -0.9,                         Validation error: nan,                         Time Elapsed: 209.5 s
# @ Iter:3000,                         Training error: -1.0,                         Validation error: nan,                         Time Elapsed: 248.9 s
# @ Iter:3500,                         Training error: -1.2,                         Validation error: nan,                         Time Elapsed: 285.0 s
# @ Iter:4000,                         Training error: -0.8,                         Validation error: nan,                         Time Elapsed: 320.6 s
# @ Iter:4500,                         Training error: -1.1,                         Validation error: nan,                         Time Elapsed: 356.7 s
# @ Iter:5000,                         Training error: -1.1,                         Validation error: nan,                         Time Elapsed: 392.9 s
# @ Iter:5500,                         Training error: -1.1,                         Validation error: nan,                         Time Elapsed: 433.1 s
# @ Iter:6000,                         Training error: -1.2,                         Validation error: nan,                         Time Elapsed: 472.5 s
# @ Iter:6500,                         Training error: -1.0,                         Validation error: nan,                         Time Elapsed: 509.3 s
# @ Iter:7000,                         Training error: -1.4,                         Validation error: nan,                         Time Elapsed: 545.8 s
# @ Iter:7500,                         Training error: -1.1,                         Validation error: nan,                         Time Elapsed: 583.7 s
# @ Iter:8000,                         Training error: -1.1,                         Validation error: nan,                         Time Elapsed: 625.0 s
# @ Iter:8500,                         Training error: -1.2,                         Validation error: nan,                         Time Elapsed: 662.4 s
# @ Iter:9000,                         Training error: -1.2,                         Validation error: nan,                         Time Elapsed: 699.4 s
# @ Iter:9500,                         Training error: -1.4,                         Validation error: nan,                         Time Elapsed: 736.7 s
# @ Iter:10000,                         Training error: -1.3,                         Validation error: nan,                         Time Elapsed: 774.9 s
# @ Iter:10500,                         Training error: -1.1,                         Validation error: nan,                         Time Elapsed: 816.7 s
# @ Iter:11000,                         Training error: -1.1,                         Validation error: nan,                         Time Elapsed: 853.8 s
# @ Iter:11500,                         Training error: -1.0,                         Validation error: nan,                         Time Elapsed: 891.3 s
# @ Iter:12000,                         Training error: -1.2,                         Validation error: nan,                         Time Elapsed: 929.0 s
# @ Iter:12500,                         Training error: -1.1,                         Validation error: nan,                         Time Elapsed: 970.8 s
# @ Iter:13000,                         Training error: -0.9,                         Validation error: nan,                         Time Elapsed: 1008.5 s
# @ Iter:13500,                         Training error: -1.2,                         Validation error: nan,                         Time Elapsed: 1046.5 s
# @ Iter:14000,                         Training error: -0.9,                         Validation error: nan,                         Time Elapsed: 1086.1 s
# @ Iter:14500,                         Training error: -1.3,                         Validation error: nan,                         Time Elapsed: 1124.3 s
# @ Iter:15000,                         Training error: -1.1,                         Validation error: nan,                         Time Elapsed: 1165.8 s
# @ Iter:15500,                         Training error: -1.2,                         Validation error: nan,                         Time Elapsed: 1204.3 s
# @ Iter:16000,                         Training error: -1.1,                         Validation error: nan,                         Time Elapsed: 1242.2 s
# @ Iter:16500,                         Training error: -1.2,                         Validation error: nan,                         Time Elapsed: 1279.9 s
# @ Iter:17000,                         Training error: -1.5,                         Validation error: nan,                         Time Elapsed: 1318.6 s
# @ Iter:17500,                         Training error: -1.0,                         Validation error: nan,                         Time Elapsed: 1361.4 s
# @ Iter:18000,                         Training error: -1.2,                         Validation error: nan,                         Time Elapsed: 1398.6 s
# @ Iter:18500,                         Training error: -1.1,                         Validation error: nan,                         Time Elapsed: 1436.3 s
# @ Iter:19000,                         Training error: -1.1,                         Validation error: nan,                         Time Elapsed: 1474.7 s
# @ Iter:19500,                         Training error: -1.3,                         Validation error: nan,                         Time Elapsed: 1516.4 s
# {'GAS': array([4.41135073, 4.57755375, 4.24145985, 4.54454708, 4.46260166,
#        4.53148937, 4.55820704, 4.66826868, 4.32659483, 4.64419651]), 'POWER': array([ 0.0482939 , -0.01393519,  0.19215031,  0.15966395, -0.05526834,
#         0.20700838,  0.09052471,  0.05195272,  0.08804642,  0.12131599])}
# Number of samples (before downsampling) = 36488, Number of dimensions = 43
# Number of training samples (after downsampling) = 10086, Number of dimensions = 43
# Learning Marginals
# Marginals learnt in 349.44 s.
# @ Iter:0,                         Training error: 11.0,                         Validation error: nan,                         Time Elapsed: 28.7 s
# @ Iter:500,                         Training error: -24.1,                         Validation error: nan,                         Time Elapsed: 250.7 s
# @ Iter:1000,                         Training error: -29.8,                         Validation error: nan,                         Time Elapsed: 474.5 s
# @ Iter:1500,                         Training error: -30.6,                         Validation error: nan,                         Time Elapsed: 701.1 s
# @ Iter:2000,                         Training error: -32.7,                         Validation error: nan,                         Time Elapsed: 918.2 s
# @ Iter:2500,                         Training error: -32.0,                         Validation error: nan,                         Time Elapsed: 1144.6 s
# @ Iter:3000,                         Training error: -35.7,                         Validation error: nan,                         Time Elapsed: 1379.3 s
# @ Iter:3500,                         Training error: -36.4,                         Validation error: nan,                         Time Elapsed: 1609.3 s
# @ Iter:4000,                         Training error: -35.1,                         Validation error: nan,                         Time Elapsed: 1836.0 s
# @ Iter:4500,                         Training error: -34.7,                         Validation error: nan,                         Time Elapsed: 2060.7 s
# @ Iter:5000,                         Training error: -35.5,                         Validation error: nan,                         Time Elapsed: 2285.5 s
# @ Iter:5500,                         Training error: -31.9,                         Validation error: nan,                         Time Elapsed: 2515.7 s
# @ Iter:6000,                         Training error: -33.8,                         Validation error: nan,                         Time Elapsed: 2742.4 s
# @ Iter:6500,                         Training error: -38.3,                         Validation error: nan,                         Time Elapsed: 2963.9 s
# @ Iter:7000,                         Training error: -38.3,                         Validation error: nan,                         Time Elapsed: 3187.9 s
# @ Iter:7500,                         Training error: -35.2,                         Validation error: nan,                         Time Elapsed: 3421.4 s
# @ Iter:8000,                         Training error: -36.6,                         Validation error: nan,                         Time Elapsed: 3648.4 s
# @ Iter:8500,                         Training error: -34.5,                         Validation error: nan,                         Time Elapsed: 3876.1 s
# @ Iter:9000,                         Training error: -35.3,                         Validation error: nan,                         Time Elapsed: 4107.9 s
# @ Iter:9500,                         Training error: -36.4,                         Validation error: nan,                         Time Elapsed: 4328.5 s
# @ Iter:10000,                         Training error: -36.5,                         Validation error: nan,                         Time Elapsed: 4557.2 s
# @ Iter:10500,                         Training error: -37.8,                         Validation error: nan,                         Time Elapsed: 4782.9 s
# @ Iter:11000,                         Training error: -38.4,                         Validation error: nan,                         Time Elapsed: 5016.0 s

# %%
plt.plot(nll_train/100)
plt.plot(nll_vld/1000,'ks')

# %%
ll_vld=gmcm_obj.distribution.log_prob(data_vld).numpy()
ll_tst=gmcm_obj.distribution.log_prob(data_tst).numpy()

# %%
[np.mean(ll_tst),np.mean(ll_vld)]

# %%
non_nan_ids=[i for i in range(len(nll_vld)) if np.isfinite(nll_vld[i])]
nll_vld_smooth=utl.moving_average(nll_vld[non_nan_ids],5)
best_num_iter=non_nan_ids[np.argmin(nll_vld_smooth)]

# %%
best_training_iters

# %%
np.isfinite(nll_vld[1])

# %%
nll_vld[1]==np.nan.astype('float64')

# %%
plt.plot(nll_vld[:200],'ks');

# %%
gg.val.x.shape

# %%
from power import POWER
gg=POWER('C:/Users/tewar/Documents/work/GMCM/data/power/data.npy')
data = gg.trn.x
nsamps,ndims = data.shape
idx_selected = np.unique(np.random.randint(0,nsamps,int(nsamps/50)))
data_in = data[idx_selected,:].astype('float32')
# data_in = np.random.randn(1000,10).astype('float32')
min_val = np.min(data_in).astype('float32')-1
shift_exp_bijec = tfb.Chain([tfb.Shift(shift=min_val.astype('float32')),tfb.Exp()])
gmcm_obj = GMCM(ndims, data_in, forward_transform=shift_exp_bijec)
ll_trn=gmcm_obj.fit_GMC_dist(5,max_iters=5,batch_size=50,initialization=['random',1], print_interval=500, regularize=True)

# %%
dl,vals = [0, 2, 3, 5], [0.1, -2, 1.2, 3.4]
marg_gmcm = gmcm_obj.get_marginal(dl)
cond_gmcm = gmcm_obj.get_conditional(dl,vals)

# %%
vv_all = np.array([0.1, 0, -2, 1.2, 0, 3.4]).astype('float32').reshape(1,-1)
vv_obs = np.array(vals).astype('float32').reshape(1,-1)
vv_unobs = np.array([0.,0.]).astype('float32').reshape(1,-1)
print(gmcm_obj.distribution.log_prob(vv_all) - marg_gmcm.distribution.log_prob(vv_obs))
print(cond_gmcm.distribution.log_prob(vv_unobs))

# %%
out1 = vec2gmm_params(gmcm_obj.ndims,gmcm_obj.ncomps,gmcm_obj.gmc.params)
out2 = vec2gmm_params(marg_gmcm.ndims, marg_gmcm.ncomps,marg_gmcm.gmc.params)
out3 = vec2gmm_params(cond_gmcm.ndims, cond_gmcm.ncomps,cond_gmcm.gmc.params)


print(tf.math.softmax(out1[0]))
print(tf.math.softmax(out2[0]))
print(tf.math.softmax(out3[0]))

# %%
data1 = gmcm_obj.distribution.sample(10000)
data2 = marg_gmcm.distribution.sample(10000)

# %%
vv =np.array([1,1.,1]).astype('float32').reshape(1,-1)
vv1 = marg_gmcm.distribution.bijector.inverse(vv)
print(vv1)
vv2 = marg_gmcm.distribution.distribution.bijector.inverse(vv1)
print(vv2)
vv3 = marg_gmcm.distribution.distribution.distribution.bijector.inverse(vv2)
print(vv3)

obj = marg_gmcm
while hasattr(obj.distribution,'bijector'):
    vv = obj.distribution.bijector.inverse(vv).numpy()
    print(vv)
    obj = obj.distribution

# %%
plt.plot(data1[:,3],data1[:,0],'k.');
plt.plot(data2[:,1],data2[:,0],'r.');

# %%
plt.semilogy(ll_trn+10)

# %%
plt.plot(ll_1)
np.mean(ll_1)

# %%
gmcm_obj.gmc.total_trainable_params

# %%
data_in_tst.shape

# %%
ss = gmcm_obj.distribution.sample(2000).numpy()

# %%
id1,id2 = np.random.choice(ndims,2)
plt.subplot(121)
plt.plot(ss[:,id1],ss[:,id2],'k.')
plt.subplot(122)
plt.plot(data_in[:,id1],data_in[:,id2],'k.')
print([id1,id2])

# %%
# plt.hist(ss[:,id2],20);
plt.hist(data_in[:,id2],50)

# %%
plt.hist(np.log(data_in[:,1]+1),50);

# %%
sys.path.append('../logs/GAS/LRminus3_NComps60/chkpt/')

# %%
@tf.function
def run_chain(init_state,step_size,target_log_prob_fn, unconstraining_bijectors=tfb.Identity(),num_steps=1000,burnin=50):
    def trace_fn(_,pkr):
        return (
            pkr.inner_results.inner_results.target_log_prob,
            pkr.inner_results.inner_results.leapfrogs_taken,
            pkr.inner_results.inner_results.has_divergence,
            pkr.inner_results.inner_results.energy,
            pkr.inner_results.inner_results.log_accept_ratio
                )
#     kernel = tfp.mcmc.TransformedTransitionKernel(
#         inner_kernel=tfp.mcmc.NoUTurnSampler(
#             target_log_prob_fn,
#             step_size=step_size),
#         bijector=unconstraining_bijectors)

#     hmc = tfp.mcmc.DualAveragingStepSizeAdaptation(
#         inner_kernel=kernel,
#         num_adaptation_steps=burnin,
#         step_size_setter_fn=lambda pkr, new_step_size: pkr._replace(
#               inner_results=pkr.inner_results._replace(step_size=new_step_size)),
#         step_size_getter_fn=lambda pkr: pkr.inner_results.step_size,
#         log_accept_prob_getter_fn=lambda pkr: pkr.inner_results.log_accept_ratio
#       )
    
    
    hmc = tfp.mcmc.TransformedTransitionKernel(
        inner_kernel=tfp.mcmc.RandomWalkMetropolis(target_log_prob_fn),
        bijector=unconstraining_bijectors) 
    
    

    # Sampling from the chain.
    return tfp.mcmc.sample_chain(
        num_results=num_steps,
        num_burnin_steps=burnin,
        current_state=init_state,
        kernel=hmc)
#         trace_fn=trace_fn)

# %%
aa=np.load('../logs/GAS/LRminus3_NComps60/chkpt/iter10000.npy')

# %%
plt.plot(aa)
aa[-1]

# %%
alpha = [0.1,0.2,0.7]
mu = np.random.randn(3,2).astype('float32')
sig = np.zeros((3,2,2)).astype('float32')
sig[0] = tfb.FillScaleTriL(diag_bijector=tfb.Exp()).forward(np.random.randn(3).astype('float32'))
sig[1] = tfb.FillScaleTriL(diag_bijector=tfb.Exp()).forward(np.random.randn(3).astype('float32'))
sig[2] = tfb.FillScaleTriL(diag_bijector=tfb.Exp()).forward(np.random.randn(3).astype('float32'))
dist=tfd.MixtureSameFamily(mixture_distribution=tfd.Categorical(probs=alpha),
                          components_distribution=tfd.MultivariateNormalTriL(loc=mu,scale_tril=sig))
ss = dist.sample(10000).numpy()
tf.reduce_mean(dist.log_prob(ss))

# %%
gmcm_obj = GMCM(2, ss)
ll_trn=gmcm_obj.fit_GMC_dist(2,max_iters=5000,batch_size=50,initialization=['random',0], print_interval=500, regularize=True)

# %%
plt.plot(ll_trn)
tf.reduce_mean(gmcm_obj.distribution.log_prob(ss))

# %%
gmcm_obj.gmc.distribution.log_prob(np.array([0.3,0.1]).astype('float32').reshape(1,-1))

def target_log_prob(u_part):
    u = tf.concat([u_part,tf.constant(0.999999,shape=(1,))],axis=0)
    u = tf.reshape(u,shape=(1,-1))
    return gmcm_obj.gmc.distribution.log_prob(u)

init_state = tf.constant(np.random.rand(1).astype('float32'))
target_log_prob(init_state)

# %%
# init_state = tf.constant(np.random.rand(2).astype('float32'))
u_init = tf.Variable(init_state)
with tf.GradientTape() as tape:
    out = target_log_prob(u_init)
grads = tape.gradient(out, u_init)
print(out)
print(grads)

grad_fd = gradientFiniteDifferent(target_log_prob,u_init,delta=1E-4)
print(grad_fd)

# %%
# Running 5 chains in parallel
n_chains = 5
init_state = tf.constant(np.random.rand(2).astype('float32'))
step_size= 0.1
# bijector to map contrained parameters to real
ts = time.time()
output_NUTS = run_chain(init_state, step_size, target_log_prob,num_steps=10,burnin=50)
print(f'NUTS runtime for {n_chains} chains: {time.time()-ts} s.')

# %%
ess = tfp.mcmc.effective_sample_size(output_NUTS.all_states)
ess = tfp.transpose(ess).numpy()
plot(ess)
total_samples_all_chains = np.prod(output_NUTS.all_states.shape[:2])
total_samples = tf.reshape(output_NUTS.all_states,shape=(total_samples_all_chains,2))

# %%
output_NUTS.all_states

# %%
u_vec = np.linspace(0.001,0.9999,50).astype('float32').reshape(-1,1)
p_vec = np.zeros(50)
for i in range(50):
    p_vec[i] = target_log_prob(u_vec[i])
    if i%10 ==0:
        print(i)

# %%
plt.plot(u_vec,tf.exp(p_vec),'k')

# %%
# # Numerically finding the icdf values for a distribution whos analytical CDF is specified
# def icdf_numerical(u,cdf_funct,lb,ub):
#     # setting up the numerical method (Chandrupatla root finding algorithm) to find icdf
#     obj_func = lambda x: cdf_funct(x) - u
#     # finding the roots
#     x = tfp.math.find_root_chandrupatla(obj_func,low=lb,high=ub)[0]
#     return x

# # Standardize GMM parameters
# def standardize_gmm_params(alphas,mus,covs):
#     weighted_mus = tf.linalg.matvec(tf.transpose(mus),alphas)
#     new_mus = mus - weighted_mus
#     variances = tf.linalg.diag_part(covs)
#     scaling_vec = tf.linalg.matvec(tf.transpose(new_mus**2+variances),alphas)
#     scaling_matrix = tf.linalg.diag(1/(scaling_vec**0.5))
#     new_mus = tf.linalg.matmul(new_mus,scaling_matrix)
#     new_covs = tf.linalg.matmul(covs,scaling_matrix**2)
#     return alphas,new_mus,new_covs

# def vec2gmm_params(n_dims,n_comps,param_vec):
#     num_alpha_params = n_comps
#     num_mu_params = n_comps*n_dims
#     num_sig_params = int(n_comps*n_dims*(n_dims+1)*0.5)
#     logit_param, mu_param, chol_param = tf.split(param_vec,[num_alpha_params,num_mu_params,num_sig_params])
#     mu_vectors = tf.reshape(mu_param, shape=(n_comps,n_dims))
#     chol_mat_array=tf.TensorArray(tf.float32,size=n_comps)
#     cov_mat_array=tf.TensorArray(tf.float32,size=n_comps)
#     for k in range(n_comps):
#         start_idx = tf.cast(k*(num_sig_params/n_comps),tf.int32)
#         end_idx = tf.cast((k+1)*(num_sig_params/n_comps),tf.int32)
#         chol_mat = tfb.FillScaleTriL(diag_bijector=tfb.Exp()).forward(chol_param[start_idx:end_idx])
#         cov_mat = tf.matmul(chol_mat,tf.transpose(chol_mat))
#         chol_mat_array = chol_mat_array.write(k,chol_mat) 
#         cov_mat_array =  cov_mat_array.write(k,cov_mat) 
        
#     chol_matrices = chol_mat_array.stack()
#     cov_matrices = cov_mat_array.stack()     
#     return [logit_param,mu_vectors,cov_matrices,chol_matrices]

# def gmm_params2vec(n_dims,n_comps,alphas,mu_vectors,cov_matrices):
#     # now gathering all the parameters into a single vector
#     param_list = []
#     param_list.append(np.log(alphas))
#     param_list.append(tf.reshape(mu_vectors,-1))
#     for k in range(n_comps):
#         chol_mat = tf.linalg.cholesky(cov_matrices[k])
#         param_list.append(tfb.FillScaleTriL(diag_bijector=tfb.Exp()).inverse(chol_mat))
#     param_vec = tf.concat(param_list,axis=0)
#     return param_vec

# %%
# # GMC bijector
# class GMC_bijector(tfb.Bijector):
#     def __init__(self,n_dims,n_comps,param_list,forward_min_event_ndims=1, validate_args: bool = False,name="gmc"):
#         super(GMC_bijector, self).__init__(
#             validate_args=validate_args, forward_min_event_ndims=forward_min_event_ndims, name=name
#         )
        
#         assert (len(param_list)==3), 'incorrect number of inputs'
#         assert param_list[1].shape == [n_comps,n_dims], 'the dimension of mean vectors should be ncomps x ndims'
#         assert param_list[2].shape == [n_comps,n_dims], 'the dimension of variance vectors should be ncomps x ndims'
        
#         self.ndims = n_dims
#         self.ncomps = n_comps
#         self.logits = param_list[0]
#         self.mu_vectors = param_list[1]
#         self.var_vectors = param_list[2]
#         self.std_vectors = self.var_vectors**0.5
    
#     def _forward(self, x_mat):
#         assert x_mat.shape[1] == self.ndims, 'expected data dimensions n_samps x n_dims'
#         dist = tfd.MixtureSameFamily(mixture_distribution=tfd.Categorical(logits=self.logits),
#                                components_distribution=tfd.Normal(loc=tf.transpose(self.mu_vectors),
#                                                                   scale=tf.transpose(self.std_vectors)))
#         u_mat = dist.cdf(x_mat)
#         return u_mat
    
#     def _inverse(self, u_mat):
#         assert u_mat.shape[1] == self.ndims, 'expected data dimensions n_samps x n_dims'
#         x_mat = self.gmm_icdf_parallel(u_mat,self.logits,tf.transpose(self.mu_vectors),tf.transpose(self.std_vectors))
#         return x_mat
    
#     def _inverse_log_det_jacobian(self, u_mat):
#         x_mat = self._inverse(u_mat)
#         dist = tfd.MixtureSameFamily(mixture_distribution=tfd.Categorical(logits=self.logits),
#                                components_distribution=tfd.Normal(loc=tf.transpose(self.mu_vectors),
#                                                                   scale=tf.transpose(self.std_vectors)))
#         log_det_J_mat = dist.log_prob(x_mat)
#         return -tf.reduce_sum(log_det_J_mat,axis=1)    
    
#     # Numerically finding the icdf values of univariate gmm distributions (one along each dimension)
#     @tf.custom_gradient
#     def gmm_icdf_parallel(self,u_mat,logit,mu_T,std_T):
#         # Setting up the numerical method to find icdf
#         # first define a function that computes the residual between the actual true CDF values and the CDF value as specified matrix
#         obj_func = lambda x: tfd.MixtureSameFamily(mixture_distribution=tfd.Categorical(logits=logit),
#                                                    components_distribution=tfd.Normal(loc=mu_T,scale=std_T)).cdf(x)-u_mat
#         # specifying the lower and upper bounds of the root based on current parameters
#         lb = tf.reduce_min(mu_T,axis=1) - 5*tf.reduce_max(std_T,axis=1)
#         ub = tf.reduce_max(mu_T,axis=1) + 5*tf.reduce_max(std_T,axis=1)
#         # replicating the lower and upper bounds
#         lb = tf.repeat(tf.reshape(lb,[1,-1]),u_mat.shape[0],axis=0)
#         ub = tf.repeat(tf.reshape(ub,[1,-1]),u_mat.shape[0],axis=0)
#         # finding the roots (Chandrupatla root finding algorithm)
#         x_mat = tfp.math.find_root_chandrupatla(obj_func,low=lb,high=ub)[0]
#         # following code implements custom gradient
#         def grad(dy):
#             # Calling  another python function to get the partial derivatives
#             grad_logit, grad_mu, grad_std = self.partial_deriv_z(x_mat,logit,mu_T,std_T)

#             temp_mat = tf.linalg.matmul(grad_logit,dy)

#             logit_grad = tf.linalg.diag_part(temp_mat)
#             logit_grad = tf.reduce_sum(logit_grad,axis=1)

#             temp_mat = tf.linalg.matmul(grad_mu,dy)
#             mu_grad = tf.linalg.diag_part(temp_mat)

#             temp_mat = tf.linalg.matmul(grad_std,dy)
#             std_grad = tf.linalg.diag_part(temp_mat)
            
#             return tf.constant(0.,shape=(u_mat.shape)), logit_grad, tf.transpose(mu_grad), tf.transpose(std_grad)    
#         return x_mat, grad
    
#     # Analytical partial derivative of icdf of Gaussian Mixture marginals
#     def partial_deriv_z(self,z,logit,mu_T,std_T):
#         alpha = tf.math.softmax(logit)
#         grad_logit_array = tf.TensorArray(tf.float32, size=self.ncomps)
#         grad_mu_array = tf.TensorArray(tf.float32, size=self.ncomps)
#         grad_var_array = tf.TensorArray(tf.float32, size=self.ncomps)        
#         dist = tfd.MixtureSameFamily(mixture_distribution=tfd.Categorical(logits=logit),
#                                 components_distribution=tfd.Normal(loc=mu_T,
#                                                                    scale=std_T))
#         common_factor1 = dist.prob(z)
#         for k in range(self.ncomps):        
#             common_factor2 = tfd.Normal(loc=mu_T[:,k],scale=std_T[:,k]).prob(z)
#             term = 0.5*(1+tf.math.erf((z-mu_T[:,k])/(tf.math.sqrt(2.)*std_T[:,k])))
#             v1 = -alpha[k]*(term - dist.cdf(z))/common_factor1
#             v2 = alpha[k]*common_factor2/common_factor1
#             v3 = v2 * ((z-mu_T[:,k])/(std_T[:,k])) 

#             grad_logit_array = grad_logit_array.write(k, tf.transpose(v1) )
#             grad_mu_array = grad_mu_array.write(k, tf.transpose(v2) )
#             grad_var_array = grad_var_array.write(k, tf.transpose(v3) )
#         return grad_logit_array.stack(), grad_mu_array.stack(), grad_var_array.stack()
    
#  # Marignal transform bijector
# class Marginal_transform(tfb.Bijector):
#     def __init__(self,ndims,marg_dist_list,forward_min_event_ndims=1, validate_args: bool = False,name="marginals"):
#         super(Marginal_transform, self).__init__(
#             validate_args=validate_args, forward_min_event_ndims=forward_min_event_ndims, name=name
#         )
#         self.ndims = ndims
#         self.marg_dists = marg_dist_list
    
#     def _inverse(self, x_mat):
#         nobs = x_mat.get_shape().as_list()[0]
#         temp_array = tf.TensorArray(tf.float32,size=self.ndims)
#         for j in range(self.ndims):
#             u_cur = self.marg_dists[j]['cdf'](x_mat[:,j])
#             temp_array = temp_array.write(j,u_cur)
#         u_mat = tf.transpose(temp_array.stack())            
#         return u_mat
    
#     def _forward(self, u_mat):
#         temp_array = tf.TensorArray(tf.float32,size=self.ndims)
#         for j in range(self.ndims):
#             x_cur = icdf_numerical(u_mat[:,j], self.marg_dists[j]['cdf'],self.marg_dists[j]['lb'],self.marg_dists[j]['ub'])
#             temp_array = temp_array.write(j,x_cur)
#         x_mat = tf.transpose(temp_array.stack())              
#         return x_mat
    
#     def _forward_log_det_jacobian(self, u_mat):
#         x_mat = self._forward(u_mat)
#         temp_array = tf.TensorArray(tf.float32,size=self.ndims)
#         for j in range(self.ndims):
#             temp_array = temp_array.write(j,self.marg_dists[j]['log_pdf'](x_mat[:,j]))
#         log_det_J_mat = tf.transpose(temp_array.stack())
#         return -tf.reduce_sum(log_det_J_mat,axis=1) 
    
#     def _inverse_log_det_jacobian(self, x_mat):
#         u_mat = self._inverse(x_mat)
#         return -self._forward_log_det_jacobian(u_mat)

# %%
# # Defining GMC class
# class GMC:
#     def __init__(self, n_dims, n_comps, param_vec):        
#         self.ndims = n_dims
#         self.ncomps = n_comps   
#         self.total_trainable_params = int(n_comps*(1+n_dims+0.5*n_dims*(n_dims+1)))
#         self.params = param_vec
#         assert tf.size(param_vec) == self.total_trainable_params, 'the supplied parameter vector is not commensurate with the n_dims, and n_comps'
        
#     @property
#     def distribution(self):
#         # transforming vector in to parameters
#         logits,mus,covs,chols = vec2gmm_params(self.ndims,self.ncomps,self.params)
#         # Instantiating the bijector
#         gmc_bijector = GMC_bijector(self.ndims, self.ncomps, [logits, mus, tf.linalg.diag_part(covs)])
#         # Specifying the base distribution
#         base_dist = tfd.MixtureSameFamily(tfd.Categorical(logits=logits),
#                                           tfd.MultivariateNormalTriL(loc=mus,scale_tril=chols))
#         # Instnatiating the gmc distribution as a transformed distribtution
#         gmc_dist = tfd.TransformedDistribution(distribution=base_dist,bijector=gmc_bijector)    
#         return gmc_dist   
    
#     @property
#     def identifiability_prior(self):
#         # transforming vector in to parameters
#         logits,mus,covs,_ = vec2gmm_params(self.ndims,self.ncomps,self.params)        
#         alphas = tf.math.softmax(logits)
#         variances = tf.linalg.diag_part(covs)        
#         vec1 = tf.linalg.matvec(tf.transpose(mus),alphas)
#         vec2 = tf.linalg.matvec(tf.transpose(variances + mus**2),alphas)
#         log_prior_1 = tfd.MultivariateNormalDiag(loc=tf.zeros(self.ndims),scale_diag=1E-1*tf.ones(self.ndims)).log_prob(vec1)
#         log_prior_2 = tfd.MultivariateNormalDiag(loc=tf.ones(self.ndims) ,scale_diag=1E-1*tf.ones(self.ndims)).log_prob(vec2)
#         return log_prior_1,log_prior_2
    

    
# class GMCM:
#     def __init__(self, n_dims, data_in, forward_transform=None, marginals_list=None, gmc=None):
        
#         self.ndims = n_dims
#         self.data_transform = forward_transform
#         self.gmc = gmc
#         if gmc is not None:
#             self.ncomps = gmc.ncomps
        
#         if forward_transform is not None:
#             data_in = forward_transform.inverse(data_in).numpy()
#         self.data_in = data_in
        
#         if marginals_list is None:
#             print('Learning Marginals')
#             ts = time.time()
#             marginals_list = self.learn_marginals()
#             print(f'Marginals learnt in {np.round(time.time()-ts,2)} s.') 
        
#         self.marg_dists = marginals_list
#         self.marg_bijector = Marginal_transform(self.ndims,self.marg_dists)       
        
#     @property
#     def distribution(self):
#         # setting the gmcm distribution as a transformed distribution of gmc_distribution
#         gmcm_dist = tfd.TransformedDistribution(distribution=self.gmc.distribution,bijector=self.marg_bijector)
#         if self.data_transform is not None:
#             gmcm_dist = tfd.TransformedDistribution(distribution=gmcm_dist,bijector=self.data_transform)
#         return gmcm_dist
    
    
#     def learn_marginals(self):
#         # fitting marginal distributions first
#         marg_dist_list=[]
#         for j in range(self.ndims):
#             input_vector = self.data_in[:,j].reshape(-1,1)
#             marg_gmm_obj = GMM_best_fit(input_vector,max_ncomp=10)
#             marg_gmm_tfp = tfd.MixtureSameFamily(mixture_distribution=tfd.Categorical(probs=marg_gmm_obj.weights_.flatten().astype('float32')),
#                                                 components_distribution=tfd.Normal(loc=marg_gmm_obj.means_.flatten().astype('float32'),
#                                                                                    scale = marg_gmm_obj.covariances_.flatten().astype('float32')**0.5),)
            
#             # creating a dictionary containing necessary information about each marginal distribution
#             info_dict={'cdf':marg_gmm_tfp.cdf,
#                        'log_pdf':marg_gmm_tfp.log_prob,
#                        'lb':tf.reduce_min(input_vector)-3*tfp.stats.stddev(input_vector),
#                        'ub':tf.reduce_max(input_vector)+3*tfp.stats.stddev(input_vector)                         
#                       }
            
#             marg_dist_list.append(info_dict)
        
#         return marg_dist_list
        
#     def init_GMC_params(self,initialization=['random',None]):
#         # Initializing the GMC params 
#         init_method, seed_val = initialization
#         if init_method == 'random':
#             if seed_val is not None:
#                 np.random.seed(seed_val)
#             alphas = tf.ones(self.ncomps)/self.ncomps
#             mus = tf.constant(np.random.randn(self.ncomps,self.ndims).astype('float32'))
#             covs = tf.repeat(tf.expand_dims(tf.eye(self.ndims),0),self.ncomps,axis=0)
#         elif init_method == 'gmm':            
#             gmm = mixture.GaussianMixture(n_components=self.ncomps,covariance_type='full',max_iter=1000,n_init=5)
#             gmm.fit(self.data_in)
#             alphas = gmm.weights_.astype('float32')
#             mus = gmm.means_.astype('float32')
#             covs = gmm.covariances_.astype('float32')                                                            
        
#         # changing the parameters to standardize the resulting gmm
#         alphas,mus,covs = standardize_gmm_params(alphas,mus,covs)
#         # now initializing trainable parameters
#         init_params = tf.Variable(gmm_params2vec(self.ndims,self.ncomps,alphas,mus,covs))
        
#         return init_params
    
    
#     def fit_GMC_dist(self, n_comps, optimizer = tf.optimizers.Adam(learning_rate=1E-2), initialization = ['random',None], max_iters = 1000, batch_size = 10, print_interval=100, regularize=True, plot_results = False):
#         self.ncomps = n_comps
#         # getting the marginal CDF values
#         u_mat = self.marg_bijector.inverse(self.data_in)
#         # initializing the parameters
#         gmc_params = self.init_GMC_params(initialization=initialization)
#         # instantiation GMC object
#         gmc_obj = GMC(self.ndims,self.ncomps,gmc_params)
        
#         # Defining the training step
#         @tf.function
#         def train_step(u_selected):
#             with tf.GradientTape() as tape:
#                 neg_gmc_ll = -tf.reduce_mean(gmc_obj.distribution.log_prob(u_selected))
#                 ident_prior = gmc_obj.identifiability_prior
#                 if regularize:
#                     total_cost = neg_gmc_ll - tf.reduce_sum(ident_prior)
#                 else:
#                     total_cost = neg_gmc_ll
                    
#             grads = tape.gradient(total_cost, gmc_obj.params)
#             if not (tf.reduce_any(tf.math.is_nan(grads)) or tf.reduce_any(tf.math.is_inf(grads))):
#                 optimizer.apply_gradients(zip([grads], [gmc_obj.params])) #updating the gmc parameters
#             return neg_gmc_ll,ident_prior[0],ident_prior[1]

#         neg_ll_trn = np.empty(max_iters)  
#         neg_ll_trn[:] = np.NaN
#         neg_prior_1 = np.empty(max_iters)  
#         neg_prior_1[:] = np.NaN
#         neg_prior_2 = np.empty(max_iters)  
#         neg_prior_2[:] = np.NaN
#         np.random.seed(10)
#         ts = time.time() # start time
#         # Optimization iterations
#         for itr in np.arange(max_iters):
#             np.random.seed(itr)
#             # Executing a training step
#             samps_idx = np.random.choice(u_mat.shape[0],batch_size)
#             u_selected_trn = tf.gather(u_mat,samps_idx)
#             out = train_step(u_selected_trn)
#             neg_ll_trn[itr] = out[0].numpy()
#             neg_prior_1[itr] = out[1].numpy()
#             neg_prior_2[itr] = out[2].numpy()    
#             # Printing results every 100 iteration    
#             if tf.equal(itr%print_interval,0) or tf.equal(itr,0):
#                 time_elapsed = np.round(time.time()-ts,1)
#                 print(f'@ Iter:{itr}, Training error: {neg_ll_trn[itr]}, LogPriors: {np.round(neg_prior_1[itr],2), np.round(neg_prior_2[itr],2)}, Time Elapsed: {time_elapsed} s')    
        
#         if plot_results:
#             # Plotting results
#             plt.plot(neg_ll_trn)
#             plt.xlabel('Iteration',fontsize=12)
#             plt.ylabel('Neg_logLike',fontsize=12)
#             plt.legend(['train'],fontsize=12)
        
#         # setting gmc distritbution embedded inside GMCM
#         self.gmc = gmc_obj
         
#         return neg_ll_trn
    
#     def get_marginal(self,dim_list):        
#         data_in_new = tf.gather(self.data_in,dim_list,axis=1).numpy()
#         logits,mus,covs,_ = vec2gmm_params(self.ndims,self.ncomps,self.gmc.params)
#         alphas = tf.math.softmax(logits)
#         dim_remove = list(set(list(range(self.ndims)))-set(dim_list))
#         mus_new = tf.gather(mus, dim_list, axis=1)
#         covs_new = tf.TensorArray(tf.float32,self.ncomps)
#         for k in range(self.ncomps):
#             temp_mat = covs[k].numpy()
#             covs_new = covs_new.write(k,temp_mat[np.ix_(dim_list,dim_list)])
#         covs_new = covs_new.stack()
#         # getting the gmc object first for the marginal gmcm
#         marginal_gmc_params = gmm_params2vec(len(dim_list),self.ncomps,alphas,mus_new,covs_new)
#         marg_gmc = GMC(len(dim_list),self.ncomps,marginal_gmc_params)
#         # then getting the marginals along the specified dimensions
#         marg_list_new = []
#         for j in range(self.ndims):
#             if j in dim_list:
#                 marg_list_new.append(self.marg_dists[j])
#         # creating the marginal gmcm object
#         marg_gmcm_dist = GMCM(len(dim_list), data_in_new, forward_transform=self.data_transform, marginals_list=marg_list_new, gmc=marg_gmc)
#         return marg_gmcm_dist   
    
#     def get_conditional(self,obs_dim_list, value_list):
        
#         x_obs = np.array(value_list).reshape(1,-1).astype('float32')
#         unobs_dim_list = list(set(range(self.ndims)) - set(obs_dim_list))
        
#         #Obtaining the marginal distribution for the observed and missing part
#         gmcm_observed = self.get_marginal(obs_dim_list)
#         gmcm_unobserved = self.get_marginal(unobs_dim_list)
        
#         temp_obj = gmcm_observed
#         z_obs = np.copy(x_obs)
#         while hasattr(temp_obj.distribution,'bijector'):
#             z_obs = temp_obj.distribution.bijector.inverse(z_obs).numpy()
#             temp_obj = temp_obj.distribution

#         #Obtaining the conditional mu and Sigma of individual compoents of the missing part given the data of observed part
#         mus_cond = np.zeros((self.ncomps,len(unobs_dim_list))).astype('float32')
#         covs_cond = np.zeros((self.ncomps,len(unobs_dim_list), len(unobs_dim_list))).astype('float32')
#         logits_cond = np.zeros(self.ncomps).astype('float32')
        
#         logits,mus,covs,_ = vec2gmm_params(self.ndims,self.ncomps,self.gmc.params)
#         logits_unobs,mus_unobs,covs_unobs,_ = vec2gmm_params(gmcm_unobserved.ndims,gmcm_unobserved.ncomps,gmcm_unobserved.gmc.params)
#         logits_obs,mus_obs,covs_obs,_ = vec2gmm_params(gmcm_observed.ndims,gmcm_observed.ncomps,gmcm_observed.gmc.params)
        
#         for k in range(self.ncomps):
#             sig_11 = covs_unobs.numpy()[k]
#             sig_22 = covs_obs.numpy()[k]
#             sig_12 = covs.numpy()[k][np.ix_(unobs_dim_list,obs_dim_list)]
#             sig_21 = sig_12.T
#             mu_11 = mus_unobs[k,:]
#             mu_22 = mus_obs[k,:]
            
# #             temp_mat1 = np.concatenate([np.concatenate([sig_11,sig_12],axis=1),np.concatenate([sig_21,sig_22],axis=1)],axis=0)
# #             temp_mat2=covs.numpy()[k]
# #             lll = unobs_dim_list+obs_dim_list
# #             temp_mat2 = temp_mat2[:,lll]
# #             temp_mat2 = temp_mat2[lll,:]
# #             print(temp_mat1-temp_mat2)
            

#             # Getting the conditional mu and Sigma
#             mu_bar = mu_11 + np.matmul(sig_12,  np.linalg.solve(sig_22,z_obs.T)).flatten()
#             sig_bar = sig_11 - np.matmul(sig_12,  np.linalg.solve(sig_22,sig_21))
#             mus_cond[k] = mu_bar
#             covs_cond[k] = (sig_bar+sig_bar.T)/2

#             # Getting the log proability of the components conditioned on the observed data
#             logits_cond[k] = logits_obs[k] + tfd.MultivariateNormalFullCovariance(loc=mus_obs[k],
#                                                                                          covariance_matrix=covs_obs[k]).log_prob(z_obs)
#         #logits to probabilities
#         alphas_cond = tf.math.softmax(logits_cond)
#         # parameter vector of the conditional gmc distribution
#         conditional_gmc_params = gmm_params2vec(len(unobs_dim_list),self.ncomps,alphas_cond,mus_cond,covs_cond)
#         cond_gmc = GMC(len(unobs_dim_list),self.ncomps,conditional_gmc_params)
#         # then getting the marginals along the specified dimensions
#         marg_list_new = []
#         for j in range(self.ndims):
#             if j in unobs_dim_list:
#                 marg_list_new.append(self.marg_dists[j])
#         # creating the conditional gmcm object
#         data_in_new = tf.gather(self.data_in,unobs_dim_list,axis=1).numpy()
#         cond_gmcm_dist = GMCM(len(unobs_dim_list), data_in_new, forward_transform=self.data_transform, marginals_list=marg_list_new, gmc=cond_gmc)
#         return cond_gmcm_dist

# %%
# fitting marginal distributions first
marg_dist_list=[]
for j in range(self.ndims):
    marg_dist_tfp=tfd.Gamma(concentration=tf.Variable(2.),rate=tf.Variable(0.5))
    # creating a dictionary containing necessary information about each marginal distribution
    info_dict={'cdf':marg_dist_tfp.cdf,
               'icdf':marg_dist_tf.quantile,
               'log_pdf':marg_dist_tfp.log_prob,
               'lb':0.,
               'ub':np.inf}
            
marg_dist_list.append(info_dict)

# %%
md=tfd.Gamma(concentration=tf.Variable(2.),rate=tf.Variable(0.5))
md.trainable_variables

# %%
md.quantile(0.98)

# %%
tf.inf

# %%
info_dict={'wdf':3,'sdf':4}
'wdf' in info_dict
